# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# small_2 = np.load('loss_hist/losses_small_2.npy')

# %%
plt.figure()

plt.plot(np.load('loss_hist/losses_1_1.npy'), color='black', label='baseline')
plt.plot(np.load('loss_hist/losses_2_1.npy'), color='C0', label='factor 2')
plt.plot(np.load('loss_hist/losses_1_2.npy'), color='C0', ls='--')
plt.plot(np.load('loss_hist/losses_5_1.npy'), color='C1', label='factor 5')
plt.plot(np.load('loss_hist/losses_1_5.npy'), color='C1', ls='--')
plt.plot(np.load('loss_hist/losses_10_1.npy'), color='C2', label='factor 10')
plt.plot(np.load('loss_hist/losses_1_10.npy'), color='C2', ls='--')

plt.xlabel('training steps [a.u.]')
plt.ylabel('loss [a.u.]')
plt.legend()
plt.savefig('performance.pdf')
plt.show()
