# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
small_2 = np.load('loss_hist/losses_small_2.npy')

# %%
plt.figure()
plt.plot(np.load('loss_hist/losses_small_2.npy'), color='C0', ls='--')
plt.plot(np.load('loss_hist/losses_small_4.npy'), color='C1', ls='--')
plt.plot(np.load('loss_hist/losses_small_10.npy'), color='C2', ls='--')
plt.plot(np.load('loss_hist/losses_2.npy'), color='C0', label='factor 2')
plt.plot(np.load('loss_hist/losses_4.npy'), color='C1', label='factor 4')
plt.plot(np.load('loss_hist/losses_10.npy'), color='C2', label='factor 10')
plt.plot(np.load('loss_hist/losses_1.npy'), color='black', label='baseline')
plt.xlabel('training steps [a.u.]')
plt.ylabel('loss [a.u.]')
plt.legend()
plt.savefig('performance.pdf')
plt.show()
